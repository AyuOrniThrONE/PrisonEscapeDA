# %% [markdown]
# # Helicopter Escapes!

# %% [markdown]
# We begin by importing some helper functions.

# %%
from helper import *

# %% [markdown]
# ## Get the Data

# %% [markdown]
# We used the [List of helicopter prison escapes](https://en.wikipedia.org/wiki/List_of_helicopter_prison_escapes) Wikipedia article. Extracted the table using Excel Get Data Feature

# %%
path = "1ex.csv"
data = data_from_source(path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[100], line 2
#       1 path = "1ex.csv"
# ----> 2 data = data_from_source(path)
#
# NameError: name 'data_from_source' is not defined
